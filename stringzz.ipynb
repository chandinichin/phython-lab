# %%
#lablist:program to perform the string operations
ch=0
while(1):
    print("*****************************************")
    print("MENU DRIVEN PROGRAM FOR STRING OPERATIONS")
    print("*****************************************")
    print("1. Creating the string: ")
    print("2. String concatenation.")
    print("3. Accessing the substring.")
    print("4. Displaying the length of the string.")
    print("5. Index value.")
    print("6. String comparison.")
    print("7. Exit.")
    ch=int(input("8. Enter your choice: "))
    if ch==1:
        string=input("Enter the string that you want to create: ")
    elif ch==2:
        string1=input("Enter the string which you want to concatenate with previous string: ")
        s=string+string1
        print("After concatenation the string is: ",s)
    elif ch==3:
        start=int(input("Enter the starting index of substring: "))
        end=int(input("Enter the ending index of substring: "))
        steps=int(input("Enter the number of steps: "))
        s=slice(start,end,steps)                                             #slice(start,end,steps)
        print("After slicing the substring obtained is: ",string[s])
    elif ch==4:
        print("The length of the given string is: ",len(string))
    elif ch==5:
        z1=input("Enter the character of which the index is to be displayed: ")
        if z1 in string:
            print("Index of given character is ",string.index(z1))
        else:
                print("Given character not found.")
    elif ch==6:
        if string==string1:
            print("Both the strings are equal")
        elif string<string1:
            print(string," is lesser than ",string1)
        else:
            print("The given strings are unequal.")
    elif ch==7:
        break
    else:
        print("Invalid choice!!!Try again!")
# Out:
# *****************************************
# MENU DRIVEN PROGRAM FOR STRING OPERATIONS
# *****************************************
# 1. Creating the string:
# 2. String concatenation.
# 3. Accessing the substring.
# 4. Displaying the length of the string.
# 5. Index value.
# 6. String comparison.
# 7. Exit.
# 8. Enter your choice: 1
# Enter the string that you want to create: chandini
# *****************************************
# MENU DRIVEN PROGRAM FOR STRING OPERATIONS
# *****************************************
# 1. Creating the string:
# 2. String concatenation.
# 3. Accessing the substring.
# 4. Displaying the length of the string.
# 5. Index value.
# 6. String comparison.
# 7. Exit.
# 8. Enter your choice: 2
# Enter the string which you want to concatenate with previous string: chinzz
# After concatenation the string is:  chandinichinzz
# *****************************************
# MENU DRIVEN PROGRAM FOR STRING OPERATIONS
# *****************************************
# ...

# %%
#program to display the student marklist
class Student:
    def __init__(self,regno,name,course,marks):
        self.name=name
        self.regno=regno
        self.course=course
        self.marks=marks
    def StudentDetails(self):
        print("register number:",self.regno)
        print("Name:",self.name)
        print("course:",self.course)
        print("marks:",self.marks)
    def total(self):
        print("total marks:",sum(marks))
    def average(self):
        total=sum(marks)
        avg=total/5
        print("average:",avg)
    def calculategrade(self):
        total=sum(marks)
        avg=total/5
        if avg >=80 and avg<=100:
            print("A grade")
        elif avg >=60 and avg<80:
            print("B Grade")
        elif avg>=45 and avg<60:
            print("C Grade")
        elif avg>=35 and avg<45:
            print("D Grade")
        elif avg<35:
            print("FAIL")
        else:
            print("invalid marks")
regno=int(input("enter register number:"))
name=input("enter  name:")
course=input("enter course:")
marks=[]
for i in range(5):
    marks.append(int(input("enter mark:")))
s1=Student(regno,name,course,marks)
s1.StudentDetails()
s1.total()
s1.average()
s1.calculategrade()
# Out:
# enter register number:1
# enter  name:abs
# enter course:bsc
# enter mark:90
# enter mark:78
# enter mark:78
# enter mark:67
# enter mark:94
# register number: 1
# Name: abs
# course: bsc
# marks: [90, 78, 78, 67, 94]
# total marks: 407
# average: 81.4
# A grade
